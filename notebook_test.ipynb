# %%
import os
import sys
import numpy as np
import pandas as pd
import pyscipopt
import pickle
from pyscipopt import Model
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt

from enviornment import Enviornment
from data_loader import load_generated, MIPLib2010Loader, MIPLib2017Loader, load_test
from reward import Reward
from utils import *

# %%
def get_instances(actions = [-1,1,2,5,10,20,30], 
                  seeds = [0,1,2,3,4], 
                  time_limit=60, 
                  priority_or_freq = 'freq', 
                  heuristics_to_run = ['veclendiving']):
    '''
        Gets the set of all instances.  Note that it filters instances which find a 
        primal solution within specified time limit.  
        Params:
            actions - a list of all the actions that the store data is with respect to.
            seeds - a list of all the seeds that the stored data is with respect to.
            time_limit - time limit for instances (used to filter out instances with no solutions.
            priority_or_freq - a string of 'priority' or 'freq' indicating the action space.
            heuristics_to_run - a list of the heuristics to run
        Returns:
            a dictionary with key value tuple as (instance, state)
    '''
    
    # load instances
    max_rows = 100000
    max_cols = 100000

    data_loader_2010 = MIPLib2010Loader(max_rows = max_rows, max_cols = max_cols)
    instances_2010 = data_loader_2010.get_instances()
    data_loader_2017 = MIPLib2017Loader(max_rows = max_rows, max_cols = max_cols)
    instances_2017 = data_loader_2017.get_instances()
    instance_names_2010 = list(map(lambda x: x[0], instances_2010))
    instance_names_2017 = list(map(lambda x: x[0], instances_2017))
    unique_2010_instances = list(map(lambda x: x.replace('miplib_2010', 'miplib_2017'), instance_names_2010))
    unique_2010_instances = list(filter(lambda x: x not in instance_names_2017, unique_2010_instances) )
    unique_2010_instances = list(map(lambda x: x.replace('miplib_2017', 'miplib_2010'), unique_2010_instances))
    instances_2010_filtered = list(filter(lambda x: x[0] in unique_2010_instances, instances_2010))
    instances = instances_2017 + instances_2010_filtered

    # dict to store instances which find bound within time limit
    under_time_limit_dict = {}
    
    # iterate through instances
    for instance, _ in instances:
        
        for action in actions:

            action_input = {'veclendiving': action}
            
            for seed in seeds:
                
                reward_path = get_rewards_write_path(instance, priority_or_freq, action_input, seed)
                try: 
                    

                    with open(reward_path, 'rb') as p:
                        reward = pickle.load(p)

                    if reward['primal_integral'] < time_limit - 0.001:
                        if not instance in under_time_limit_dict:
                            under_time_limit_dict[instance] = reward['state']        
                            
                except:
                    if instance in under_time_limit_dict:
                        del under_time_limit_dict[instance]
                    print(reward_path)
                    print('  ', instance, action, seed)
                        
    return under_time_limit_dict

# %%
class LinUCB(object):
    
    
    def __init__(self, actions, state_dim, alpha = 0.1):
        '''
            actions - a list of the actions as strings.
            state_dim - the state dimension of the problem.
            alpha_dim - coefficient for UCB.
        '''
        
        self.actions = actions
        self.state_dim = state_dim
        self.alpha = alpha 
        
        self.theta_a = {}
        self.A_a = {}
        self.b_a = {}
        
        # initialize linear weights
        for action in self.actions:    
            
            self.theta_a[action] = np.zeros(self.state_dim)
            self.A_a[action] = np.eye(self.state_dim)
            self.b_a[action] = np.zeros(self.state_dim)
            
        self.t = 0
        
        
    def get_action(self, state): 
        '''
            Greedily gets an action based on store parameters and UCB.
            Params:
                state - a numpy array of the state
            Returns:
                the action assosiated with the highest expected return.
        '''
        
        action_scores = np.zeros(len(self.actions))
        
        for i  in range(len(self.actions)):
            
            action = self.actions[i]
            
            A_a_inv = np.linalg.inv(self.A_a[action])
            b_a = self.b_a[action]
            theta_hat_a = np.dot(A_a_inv, b_a)
            p_a = np.dot(theta_hat_a, state) + self.alpha*np.sqrt(np.dot(state.T, np.dot(A_a_inv, state)))
            
            action_scores[i] = p_a
                
        # break ties arbitrarily
        best_action_index = np.random.choice(np.flatnonzero(action_scores == action_scores.max()))
        best_action = self.actions[best_action_index]
        
        return best_action
    
    
        
    def get_best_action(self, state): 
        '''
            Greedily gets an action based on store parameters.  Does not use UCB.
            Params:
                state - a numpy array of the state
            Returns:
                the action assosiated with the highest expected return.
        '''
        
        action_scores = np.zeros(len(self.actions))
        
        for i  in range(len(self.actions)):
            
            action = self.actions[i]
            
            A_a_inv = np.linalg.inv(self.A_a[action])
            b_a = self.b_a[action]
            theta_hat_a = np.dot(A_a_inv, b_a)
            p_a = np.dot(theta_hat_a, state) 
            
            action_scores[i] = p_a
            
        # break ties arbitrarily
        best_action_index = np.random.choice(np.flatnonzero(action_scores == action_scores.max()))
        best_action = self.actions[best_action_index]
        
                
        return best_action
    
    
    def update_params(self, reward, state, action):
        '''
            Updates parameters given a reward, state, and action
        '''
        
        self.A_a[action] = self.A_a[action] + np.outer(state, state)
        self.b_a[action] = self.b_a[action] + reward*state
        
        return

# %%
def get_train_test_split(instances, tr_te_split_ratio=0.8):
    '''
        Gets a train, test split from the data randomly.
        Params:
            instances - a dictionary of the instances (instance:state) pairs.
            tr_te_split_ratio - the train/test ratio of the data.  
        Returns:
            two dictionaries split randomly as train and test data. 
    '''
    
    # get train/test indicies
    perm = np.random.permutation(len(instances))
    train_idx = perm[:int(tr_te_split_ratio*(len(instances)))]
    test_idx = perm[int(tr_te_split_ratio*(len(instances))):]

    # fill train/test sets
    count = 0
    train_instances = {}
    test_instances = {}
    
    for instance, state in instances.items():
        if count in train_idx:
            train_instances[instance] = state
        else:
            test_instances[instance] = state
        count += 1
        
    return train_instances, test_instances

# %%
def get_random_instance(instances):
    '''
        Chooses a random instance from the set of train and test instances.  
        Params:
            instances - a dict of the instances.
        Returns:
            a tuple of the instance name and the state as a numpy array. 
    '''
    
    # select a random instances
    rand_instance = np.random.randint(len(instances))
    
    instance = list(instances.keys())[rand_instance]
    state = instances[instance]
    
    state_as_arr = np.array(list(state.values()))
    
    return instance, state_as_arr

# %%
def take_action_on_instance(instance, action, seed=None, priority_or_freq = 'freq', heuristic = 'veclendiving'):
    '''
        Takes action on instance.
        Params:
            instance - a dict of the instances.
            action - the action to take
            seed - a seed for choosing the instance, if not specified then choose one at random.
        Returns:
            the negative primal integral
    '''
    
    # choose seed if not specified
    if seed is None:
        seed = np.random.randint(5)
        
    # cast acton tp doct
    action_dict = {
        heuristic : action
    }
    
    # get reward assosiated with action/instance/seed
    reward_path = get_rewards_write_path(instance, priority_or_freq, action_dict, seed)
    with open(reward_path, 'rb') as p:
        reward = pickle.load(p)

    return - reward['primal_integral']

# %%
def eval_on_all(bandit, instances, seeds = [0,1,2,3,4]):
    '''
        Greedily evaluates the bandit on all specified instances.  The evaluation is run across
        all seeds.
        Params:
            bandit - a trained bandit
            instances - a dict of the instances
        Returns:
            a tuple of the average reward, and the actions
    '''
    
    total_reward = 0
    actions = []
    
    for instance, state in instances.items():
        
        ep_reward = 0
        for seed in seeds:
            state_as_arr = np.array(list(state.values()))

            action = bandit.get_action(state_as_arr)
            reward = take_action_on_instance(instance, action, seed)

            ep_reward += reward
        avg_ep_reward = ep_reward / len(seeds)
        
        total_reward += avg_ep_reward
        
    avg_reward = total_reward / len(instances)
    
    return avg_reward, actions

# %%
def compute_optimal_action_reward(instances, actions, seeds=[0,1,2,3,4]):
    '''
        Computes the optimal reward for each instance by checking all actions.  
        Params:
            instances - 
            actions - 
            seeds - 
        Returns:
            the optimal reward given the action
    '''

    opt_instance_rewards = []
    
    for instance in instances.keys():
        
        opt_action = -1
        opt_action_reward = -1e7
        
        for action in actions:
            
            # compute reward across all instances
            instance_action_reward = 0
            for seed in seeds:
                reward = take_action_on_instance(instance, action, seed)
                instance_action_reward += reward
            instance_action_reward = instance_action_reward / len(seeds)
            
            if instance_action_reward > opt_action_reward:
                opt_action_reward = instance_action_reward
                opt_action = action
                
        opt_instance_rewards.append(opt_action_reward)
        
    opt_val = np.mean(opt_instance_rewards)
    return opt_val

# %%
def compute_scip_action_reward(instances, seeds=[0,1,2,3,4]):
    '''
        Computes the optimal reward for each instance by checking all actions.  
        Params:
            instances - 
            seeds - 
        Returns:
            the optimal reward given the action
    '''

    scip_rewards = []
    
    scip_action = 10
    
    
    for instance in instances.keys():
            
        # compute reward across all instances
        scip_reward = 0
        for seed in seeds:
            reward = take_action_on_instance(instance, scip_action, seed)
            scip_reward += reward
        scip_reward = scip_reward / len(seeds)
            
        scip_rewards.append(scip_reward)
        
    scip_avg_reward = np.mean(scip_rewards)
    
    return scip_avg_reward

# %%
def get_scaler_normalize_train_states(train_instances):
    '''
        Get a scaler for the input. 
        Params:
            train_instances - a dict of the training instances. 
        Returns:
            returns a sklearn scaler.   
    '''
    train_states = list(train_instances.values())

    train_states = list(map(lambda x: (list(x.values())), train_states))
    train_states = np.array(train_states)
    
    scaler = MinMaxScaler()
    scaler.fit(train_states)
    
    return scaler

# %% [markdown]
# ## Test

# %%
np.random.seed(0)

# %%
actions = [-1, 1, 10]
#actions = [-1, 1, 2, 5, 10, 20, 30]

time_limit = 60*5
state_dim = 5

# %%
instances = get_instances(actions=actions, time_limit=time_limit)
train_instances, test_instances = get_train_test_split(instances)

print(len(train_instances))
print(len(test_instances))
# Out:
# 273
# 69

# %%
scaler = get_scaler_normalize_train_states(train_instances)

# %%
episodes = 1000

seed = 1234
n_runs = 5

# %%
alpha = 0.75
bandit = LinUCB(actions, state_dim, alpha)

# %%
train_rewards = []
train_actions = []

test_rewards = []
test_actions = []

for run in range(n_runs):
    
    print('Run:', run+1)
    np.random.seed(seed + run)
    
    train_rewards_ep = []
    train_actions_ep = []

    test_rewards_ep = []
    test_actions_ep = []

    for episode in range(episodes):
        
        if (episode + 1) % 100 == 0:
            print('  episode:', episode + 1)

        instance, state = get_random_instance(train_instances)

        state = scaler.transform(state.reshape(1,state_dim)).reshape(state_dim,)
        action = bandit.get_action(state)

        reward = take_action_on_instance(instance, action)

        bandit.update_params(reward, state, action)

        train_reward, _ = eval_on_all(bandit, train_instances)
        test_reward, _ = eval_on_all(bandit, test_instances)

        train_rewards_ep.append(train_reward)
        #train_actions.append(train_action)
        test_rewards_ep.append(test_reward)
        #test_actions.append(test_action)
        
    train_rewards.append(train_rewards_ep)
    test_rewards.append(test_rewards_ep)
# Out:
# Run: 1
#   episode: 100
#   episode: 200
#   episode: 300
#   episode: 400
#   episode: 500
#   episode: 600
#   episode: 700
#   episode: 800
#   episode: 900
#   episode: 1000
# Run: 2
#   episode: 100
#   episode: 200
#   episode: 300
#   episode: 400
#   episode: 500
#   episode: 600
#   episode: 700
#   episode: 800
#   episode: 900
#   episode: 1000
# Run: 3
#   episode: 100
#   episode: 200
#   episode: 300
#   episode: 400
#   episode: 500
#   episode: 600
#   episode: 700
#   episode: 800
#   episode: 900
#   episode: 1000
# Run: 4
#   episode: 100
#   episode: 200
#   episode: 300
#   episode: 400
#   episode: 500
#   episode: 600
#   episode: 700
#   episode: 800
#   episode: 900
#   episode: 1000
# Run: 5
#   episode: 100
#   episode: 200
#   episode: 300
#   episode: 400
#   episode: 500
#   episode: 600
#   episode: 700
#   episode: 800
#   episode: 900

# %%
train_rewards_mean = np.mean(train_rewards, axis=0)
test_rewards_mean = np.mean(test_rewards, axis=0)

# %%
# get optimal rewards for train and test
train_opt = compute_optimal_action_reward(train_instances, actions)
test_opt = compute_optimal_action_reward(test_instances, actions)

# get scip default rewards for train and test
train_scip_reward = compute_scip_action_reward(train_instances)
test_scip_reward = compute_scip_action_reward(test_instances)

# %%
plt.plot(train_rewards[0])
plt.plot(train_rewards_mean)
#plt.plot(train_rewards_mean)
plt.hlines(train_scip_reward, 0, episodes)
plt.hlines(train_opt, 0, episodes)

plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Train reward per episode')

plt.show()

# %%
plt.plot(test_rewards_mean)
plt.hlines(test_scip_reward, 0, episodes)
#plt.hlines(test_opt, 0, episodes)

plt.ylabel('Reward')
plt.title('Test reward per episode')

plt.show()

# %%
# load instances
max_rows = 100000
max_cols = 100000

data_loader_2010 = MIPLib2010Loader(max_rows = max_rows, max_cols = max_cols)
instances_2010 = data_loader_2010.get_instances()

data_loader_2017 = MIPLib2017Loader(max_rows = max_rows, max_cols = max_cols)
instances_2017 = data_loader_2017.get_instances()


instance_names_2010 = list(map(lambda x: x[0], instances_2010))
instance_names_2017 = list(map(lambda x: x[0], instances_2017))

unique_2010_instances = list(map(lambda x: x.replace('miplib_2010', 'miplib_2017'), instance_names_2010))
unique_2010_instances = list(filter(lambda x: x not in instance_names_2017, unique_2010_instances) )
unique_2010_instances = list(map(lambda x: x.replace('miplib_2017', 'miplib_2010'), unique_2010_instances))

instances_2010_filtered = list(filter(lambda x: x[0] in unique_2010_instances, instances_2010))

instances = instances_2017 + instances_2010_filtered

# %%
print(len(instances_2010_filtered))
# Out:
# 79

# %%
total_instances = 0
total_instances += len(instances_2010_filtered)
total_instances += len(instances_2017)

print('2010 instances:', len(instances_2010_filtered))
print('2017 instances:', len(instances_2017))
print('Total instances:', total_instances)
# Out:
# 2010 instances: 79
# 2017 instances: 376
# Total instances: 455

# %%
print(len(instances))
# Out:
# 455

# %%
for instance in instances:
    print(instance)
    name = instance[0]
    
    model = Model()
    model.readProblem(name)
# Out:
# ('data/miplib_2017/collection/30_70_45_05_100.mps', 9.0)
# ('data/miplib_2017/collection/30_70_45_095_100.mps', 3.0)
# ('data/miplib_2017/collection/30_70_45_095_98.mps', 12.0)
# ('data/miplib_2017/collection/30n20b8.mps', 302.0)
# ('data/miplib_2017/collection/50v-10.mps', 3311.179984)
# ('data/miplib_2017/collection/a1c1s1.mps', 11503.44413)
# ('data/miplib_2017/collection/a2c1s1.mps', 10889.13763)
# ('data/miplib_2017/collection/academictimetablesmall.mps', 0.0)
# ('data/miplib_2017/collection/acc-tight2.mps', 0.0)
# ('data/miplib_2017/collection/acc-tight4.mps', 0.0)
# ('data/miplib_2017/collection/acc-tight5.mps', 0.0)
# ('data/miplib_2017/collection/aflow30a.mps', 1158.0)
# ('data/miplib_2017/collection/aflow40b.mps', 1168.0)
# ('data/miplib_2017/collection/air04.mps', 56137.0)
# ('data/miplib_2017/collection/air05.mps', 26374.0)
# ('data/miplib_2017/collection/aligninq.mps', 2713.0)
# ('data/miplib_2017/collection/app1-1.mps', -3.0)
# ('data/miplib_2017/collection/app1-2.mps', -41.0)
# ('data/miplib_2017/collection/assign1-5-8.mps', 212.0)
# ('data/miplib_2017/collection/atlanta-ip.mps', 90.00987861)
# ('data/miplib_2017/collection/b-ball.mps', -1.5)
# ('data/miplib_2017/collection/b1c1s1.mps', 24544.25)
# ('data/miplib_2017/collection/bab5.mps', -106411.8401)
# ('data/miplib_2017/collection/beasleyC2.mps', 144.0)
# ('data/miplib_2017/collection/beasleyC3.mps', 754.0)
# ('data/miplib_2017/collection/berlin.mps', 1044.0)
# ('data/miplib_2017/collection/biella1.mps', 3065005.78)
# ('data/miplib_2017/collection/bienst1.mps', 46.75)
# ('data/miplib_2017/collection/bienst2.mps', 54.6)
# ('data/miplib_2017/collection/binkar10_1.mps', 6742.199884)
# ('data/miplib_2017/collection/blp-ar98.mps', 6205.21471)
# ('data/miplib_2017/collection/blp-ic97.mps', 4025.023581)
# ('data/miplib_2017/collection/blp-ic98.mps', 4491.447584)
# ('data/miplib_2017/collection/blp-ir98.mps', 2342.315488)
# ('data/miplib_2017/collection/bnatt400.mps', 1.0)
# ('data/miplib_2017/collection/bppc4-08.mps', 53.0)
# ('data/miplib_2017/collection/bppc8-09.mps', 472.0)
# ('data/miplib_2017/collection/brasil.mps', 13655.0)
# ('data/miplib_2017/collection/brazil3.mps', 24.0)
# ('data/miplib_2017/collection/cbs-cta.mps', 0.0)
# ('data/miplib_2017/collection/chromaticindex1024-7.mps', 4.0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-91c90079feb2> in <module>
#       4
#       5     model = Model()
# ----> 6     model.readProblem(name)
#
# KeyboardInterrupt:

# %%
len(instances)
# Out:
# 455

# %%
num_actions = 3
num_seeds = 5
time_mins = 3

n_procs = 6

# %%
total_mins = num_actions * num_seeds * total_instances * time_mins
total_hours = total_mins / 60

# %%
total_hours / n_procs
# Out:
# 56.875

# %%
def get_stats(result_1, result_10, result_m1, reward_1, reward_10, reward_m1, seed, heur):
    
    r_1 = result_1.replace('seedx', 'seed' + str(seed))
    r_10 = result_10.replace('seedx', 'seed' + str(seed))
    r_m1 = result_m1.replace('seedx', 'seed' + str(seed))
    
    with open(r_1, 'r') as f:
        lines_1 = f.readlines()

    with open(r_10, 'r') as f:
        lines_10 = f.readlines()

    with open(r_m1, 'r') as f:
        lines_m1 = f.readlines()

    rp_1 = reward_1.replace('seedx', 'seed' + str(seed))
    rp_10 = reward_10.replace('seedx', 'seed' + str(seed))
    rp_m1 = reward_m1.replace('seedx', 'seed' + str(seed))
        
    with open(rp_1, 'rb') as p:
        pi_1 = pickle.load(p)['primal_integral']
        
    with open(rp_10, 'rb') as p:
        pi_10 = pickle.load(p)['primal_integral']
        
    with open(rp_m1, 'rb') as p:
        pi_m1 = pickle.load(p)['primal_integral']
        
        
    line_1_vl = list(filter(lambda x: heur in x, lines_1))
    line_10_vl = list(filter(lambda x: heur in x, lines_10))
    line_m1_vl = list(filter(lambda x: heur in x, lines_m1))

    cols = ['seed', heur + '_freq', 'PrimalIntegral', 'ExecTime', 'SetupTime', 'Calls', 'Found', 'Best']

    d = []

    e_1 = line_1_vl[0].split(" ")
    e_1 = list(filter(lambda x: x != '' and x != ':' and x != heur, e_1))
    e_1 = [seed, '1', pi_1] + e_1 
    e_1[-1] = e_1[-1].replace('\n', '')
    e_1 = list(map(lambda x: float(x), e_1))

    e_10 = line_10_vl[0].split(" ")
    e_10 = list(filter(lambda x: x != '' and x != ':' and x != heur, e_10))
    e_10 = [seed, '10', pi_10] + e_10
    e_10[-1] = e_10[-1].replace('\n', '')
    e_10 = list(map(lambda x: float(x), e_10))

    e_m1 = line_m1_vl[0].split(" ")
    e_m1 = list(filter(lambda x: x != '' and x != ':' and x != heur, e_m1))
    e_m1 = [seed, '-1', pi_m1] + e_m1
    e_m1[-1] = e_m1[-1].replace('\n', '')
    e_m1 = list(map(lambda x: float(x), e_m1))

    d = [e_1, e_10, e_m1]

    df = pd.DataFrame(d, columns=cols)
    '''
    cols = ['veclendiving_freq', 'Calls', 'Nodes', 'LP Iters', 'Backtracks', 'Conflicts', 'MinDepth', 'MaxDepth', 
     'AvgDepth', 'RoundSols', 'NLeafSols', 'MinSolDpt', 'MaxSolDpt', 'AvgSolDpt']

    d = []

    e_1 = line_1_vl[1].split(" ")
    e_1 = list(filter(lambda x: x != '' and x != ':' and x != 'veclendiving', e_1))
    e_1 = ['1'] + e_1
    e_1[-1] = e_1[-1].replace('\n', '')

    e_10 = line_10_vl[1].split(" ")
    e_10 = list(filter(lambda x: x != '' and x != ':' and x != 'veclendiving', e_10))
    e_10 = ['10'] + e_10
    e_10[-1] = e_10[-1].replace('\n', '')

    e_m1 = line_m1_vl[1].split(" ")
    e_m1 = list(filter(lambda x: x != '' and x != ':' and x != 'veclendiving', e_m1))
    e_m1 = ['-1'] + e_m1
    e_m1[-1] = e_m1[-1].replace('\n', '')

    d = [e_1, e_10, e_m1]

    df_2 = pd.DataFrame(d, columns=cols)
    '''
    df_2 = None

    return df, df_2

# %%
#results

# %%
seeds = [0,1,2,3,4]
#seeds = [0,1]
heur = 'veclendiving'
results = os.listdir('results/')

results = list(filter(lambda x: heur + '_10.txt' in x, results))
results = list(map(lambda x: 'results/' + x, results))
results = list(filter(lambda x: 'seed' + str(len(seeds)-1) in x, results))
results = list(map(lambda x: x.replace('seed' + str(len(seeds)-1), 'seedx'), results))

# %%
print(len(results))
# Out:
# 450

# %%
for idx in range(len(results)):
    
    # get results/results for index
    result_10 = results[idx]
    result_1 = result_10.replace(heur + '_10', heur + '_1')
    result_m1 = result_1.replace(heur + '_1', heur + '_-1')

    reward_10 = result_10.replace('results/', 'rewards/').replace('txt', 'pickle')
    reward_1 = reward_10.replace(heur + '_10', heur + '_1')
    reward_m1 = reward_1.replace(heur + '_1', heur + '_-1')


    print('Instance: ', result_1)

    # get dataframes for each seed and concat
    dfs = []
    for seed in seeds:
        df, _ = get_stats(result_1, result_10, result_m1, reward_1, reward_10, reward_m1, seed, heur)
        dfs.append(df)

    stats = pd.concat(dfs).sort_values([heur + '_freq', 'seed'])
    
    
    for val in [1, 10, -1]:
    
        avg = stats[np.abs(stats[heur + '_freq'] - val) <= 1e-2].mean()

        print('  freq:', val)
        print('    PrimalIntegral  :', avg['PrimalIntegral'])
        print('    ExecTime        :', avg['ExecTime'])
        print('    Calls           :', avg['Calls'])
        print('    Found           :', avg['Found'])
# Out:
# Instance:  results/30n20b8_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 157.32050796408052
#     ExecTime        : 1.0
#     Calls           : 16.0
#     Found           : 3.5
#   freq: 10
#     PrimalIntegral  : 250.48067757934587
#     ExecTime        : 0.0
#     Calls           : 3.0
#     Found           : 1.0
#   freq: -1
#     PrimalIntegral  : 153.0889452973519
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/30_70_45_05_100_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/30_70_45_095_100_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/30_70_45_095_98_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/50v-10_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 80.59560263978312
#     ExecTime        : 10.0
#     Calls           : 242.5
#     Found           : 47.5
#   freq: 10
#     PrimalIntegral  : 83.34113301337285
#     ExecTime        : 8.0
#     Calls           : 216.5
#     Found           : 34.5
#   freq: -1
#     PrimalIntegral  : 102.32303784228358
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/a1c1s1_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 105.03591707236413
#     ExecTime        : 33.0
#     Calls           : 140.0
#     Found           : 12.5
#   freq: 10
#     PrimalIntegral  : 75.51617378228867
#     ExecTime        : 22.0
#     Calls           : 287.0
#     Found           : 12.5
#   freq: -1
#     PrimalIntegral  : 208.78326337498012
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/a2c1s1_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 110.28224364293224
#     ExecTime        : 40.5
#     Calls           : 127.0
#     Found           : 19.5
#   freq: 10
#     PrimalIntegral  : 114.08616673990801
#     ExecTime        : 24.0
#     Calls           : 116.5
#     Found           : 12.0
#   freq: -1
#     PrimalIntegral  : 299.99999999999994
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/academictimetablesmall_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/acc-tight2_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 281.0
#     ExecTime        : 1.5
#     Calls           : 1.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 151.5
#     ExecTime        : 2.0
#     Calls           : 2.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 139.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/acc-tight4_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 215.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 254.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/acc-tight5_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 3.5
#     Calls           : 12.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 3.0
#     Calls           : 11.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/aflow30a_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 16.99904482761373
#     ExecTime        : 1.0
#     Calls           : 117.5
#     Found           : 6.5
#   freq: 10
#     PrimalIntegral  : 13.921389115332627
#     ExecTime        : 0.5
#     Calls           : 23.0
#     Found           : 0.5
#   freq: -1
#     PrimalIntegral  : 22.017649025695885
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/aflow40b_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 91.96995268074832
#     ExecTime        : 27.5
#     Calls           : 90.5
#     Found           : 2.0
#   freq: 10
#     PrimalIntegral  : 108.26424938298338
#     ExecTime        : 30.0
#     Calls           : 93.5
#     Found           : 4.5
#   freq: -1
#     PrimalIntegral  : 219.1105885639784
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/air04_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 26.281909420536557
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 33.68227645914936
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 32.065184719871326
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/air05_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 19.605352160436098
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 25.677375395269387
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 20.795641504325918
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/aligninq_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 98.27366010565811
#     ExecTime        : 4.0
#     Calls           : 46.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 87.59937016804209
#     ExecTime        : 3.5
#     Calls           : 33.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 60.71935472236321
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/app1-1_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 4.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 4.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 4.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/app1-2_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/assign1-5-8_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 8.506763028371674
#     ExecTime        : 12.5
#     Calls           : 973.5
#     Found           : 9.5
#   freq: 10
#     PrimalIntegral  : 7.788596244845731
#     ExecTime        : 20.5
#     Calls           : 1098.0
#     Found           : 9.0
#   freq: -1
#     PrimalIntegral  : 108.35928281982115
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/atlanta-ip_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/b-ball_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 1.3333523375018461
#     ExecTime        : 4.5
#     Calls           : 2105.5
#     Found           : 2.0
#   freq: 10
#     PrimalIntegral  : 1.5000037890786069
#     ExecTime        : 6.5
#     Calls           : 2269.0
#     Found           : 1.5
#   freq: -1
#     PrimalIntegral  : 2.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/b1c1s1_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 143.90259304147634
#     ExecTime        : 28.0
#     Calls           : 149.0
#     Found           : 9.0
#   freq: 10
#     PrimalIntegral  : 117.09450509863515
#     ExecTime        : 36.0
#     Calls           : 165.5
#     Found           : 14.5
#   freq: -1
#     PrimalIntegral  : 299.99999999999994
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/bab5_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/beasleyC2_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 27.970536120945596
#     ExecTime        : 2.0
#     Calls           : 59.0
#     Found           : 10.0
#   freq: 10
#     PrimalIntegral  : 26.199154149710854
#     ExecTime        : 3.5
#     Calls           : 43.0
#     Found           : 14.5
#   freq: -1
#     PrimalIntegral  : 21.45074273828547
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/beasleyC3_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 82.8309406108857
#     ExecTime        : 10.0
#     Calls           : 75.0
#     Found           : 0.5
#   freq: 10
#     PrimalIntegral  : 80.44177821711358
#     ExecTime        : 8.5
#     Calls           : 81.0
#     Found           : 3.5
#   freq: -1
#     PrimalIntegral  : 62.091335532563576
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/csched010_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 177.83366972523376
#     ExecTime        : 13.0
#     Calls           : 171.5
#     Found           : 2.0
#   freq: 10
#     PrimalIntegral  : 176.83839561469344
#     ExecTime        : 13.0
#     Calls           : 127.0
#     Found           : 0.5
#   freq: -1
#     PrimalIntegral  : 265.92896874102314
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/cvs08r139-94_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 74.4094827586207
#     ExecTime        : 3.0
#     Calls           : 8.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 111.56034482758622
#     ExecTime        : 2.0
#     Calls           : 8.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 192.52586206896552
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/cvs16r106-72_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/cvs16r128-89_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/cvs16r70-62_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 291.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 264.4047619047619
#     ExecTime        : 0.5
#     Calls           : 9.5
#     Found           : 1.5
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/cvs16r89-60_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 234.9153846153846
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/dano3_3_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/dano3_5_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/danoint_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 39.91770702421568
#     ExecTime        : 27.0
#     Calls           : 280.5
#     Found           : 2.0
#   freq: 10
#     PrimalIntegral  : 49.374793510972026
#     ExecTime        : 13.5
#     Calls           : 181.0
#     Found           : 0.5
#   freq: -1
#     PrimalIntegral  : 69.0029447984347
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/decomp2_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 287.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 124.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 154.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/drayage-100-12_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/drayage-100-23_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/drayage-25-23_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/drayage-25-27_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/drayage-25-32_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/eil33-2_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 19.19662796683952
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 20.373707433899767
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 19.277230892749913
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/eilA101-2_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/eilC76-2_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 77.09334839735737
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 67.6312964460958
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 90.77064691797493
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/enlight_hard_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 1.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 1.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 1.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/ex10_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/ex9_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/exp-1-500-5-5_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 21.596660400232274
#     ExecTime        : 7.5
#     Calls           : 135.5
#     Found           : 11.5
#   freq: 10
#     PrimalIntegral  : 18.396021485960986
#     ExecTime        : 1.5
#     Calls           : 61.5
#     Found           : 8.0
#   freq: -1
#     PrimalIntegral  : 75.9820444954569
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/fast0507_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 66.71271849263596
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 65.13863882966217
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 67.16141354042577
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/fastxgemm-n2r6s0t2_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 138.26296325686073
#     ExecTime        : 31.5
#     Calls           : 302.0
#     Found           : 3.5
#   freq: 10
#     PrimalIntegral  : 221.6468220747032
#     ExecTime        : 35.0
#     Calls           : 325.5
#     Found           : 3.5
#   freq: -1
#     PrimalIntegral  : 222.73235083820788
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/lectsched-5-obj_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 3.5
#     Calls           : 18.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 9.0
#     Calls           : 16.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/leo1_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 49.92426253104293
#     ExecTime        : 28.0
#     Calls           : 95.5
#     Found           : 3.0
#   freq: 10
#     PrimalIntegral  : 54.801075953501694
#     ExecTime        : 24.0
#     Calls           : 81.0
#     Found           : 3.0
#   freq: -1
#     PrimalIntegral  : 131.89985078446995
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/leo2_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 100.73273645348411
#     ExecTime        : 2.0
#     Calls           : 11.5
#     Found           : 3.0
#   freq: 10
#     PrimalIntegral  : 75.20141480998083
#     ExecTime        : 6.0
#     Calls           : 17.0
#     Found           : 3.5
#   freq: -1
#     PrimalIntegral  : 141.01531395456806
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/loopha13_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 14.0
#     Calls           : 23.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 9.5
#     Calls           : 15.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/lotsize_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 182.51608538105023
#     ExecTime        : 27.0
#     Calls           : 56.5
#     Found           : 3.0
#   freq: 10
#     PrimalIntegral  : 214.89431343850683
#     ExecTime        : 17.0
#     Calls           : 27.5
#     Found           : 2.5
#   freq: -1
#     PrimalIntegral  : 299.99999999999557
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/mad_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 269.8384972264118
#     ExecTime        : 4.5
#     Calls           : 793.0
#     Found           : 11.0
#   freq: 10
#     PrimalIntegral  : 273.9443171043446
#     ExecTime        : 6.5
#     Calls           : 909.5
#     Found           : 9.5
#   freq: -1
#     PrimalIntegral  : 269.478451798815
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/markshare1_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 283.1362220085555
#     ExecTime        : 13.0
#     Calls           : 8388.0
#     Found           : 304.0
#   freq: 10
#     PrimalIntegral  : 286.71260858282227
#     ExecTime        : 20.5
#     Calls           : 13221.5
#     Found           : 358.0
#   freq: -1
#     PrimalIntegral  : 287.0591806479663
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/markshare_4_0_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 169.5691706561911
#     ExecTime        : 10.0
#     Calls           : 13237.5
#     Found           : 279.5
#   freq: 10
#     PrimalIntegral  : 145.8395806137009
#     ExecTime        : 4.0
#     Calls           : 6930.0
#     Found           : 217.0
#   freq: -1
#     PrimalIntegral  : 196.0201951951952
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/markshare_5_0_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 251.00853092060257
#     ExecTime        : 10.0
#     Calls           : 10597.5
#     Found           : 307.5
#   freq: 10
#     PrimalIntegral  : 274.85268140589574
#     ExecTime        : 10.5
#     Calls           : 10079.0
#     Found           : 307.5
#   freq: -1
#     PrimalIntegral  : 261.9369331688496
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/mas74_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 26.259414289703457
#     ExecTime        : 15.0
#     Calls           : 7685.5
#     Found           : 9.5
#   freq: 10
#     PrimalIntegral  : 22.617406024572453
#     ExecTime        : 31.0
#     Calls           : 6839.0
#     Found           : 11.5
#   freq: -1
#     PrimalIntegral  : 69.43440516992833
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/mas76_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 8.851926504948839
#     ExecTime        : 17.0
#     Calls           : 5197.0
#     Found           : 9.5
#   freq: 10
#     PrimalIntegral  : 5.488674029883332
#     ExecTime        : 8.5
#     Calls           : 4878.0
#     Found           : 9.0
#   freq: -1
#     PrimalIntegral  : 7.0383636741519755
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/mc11_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 67.34229382850299
#     ExecTime        : 14.5
#     Calls           : 55.0
#     Found           : 1.0
#   freq: 10
#     PrimalIntegral  : 69.58680286665006
#     ExecTime        : 15.0
#     Calls           : 52.5
#     Found           : 1.5
#   freq: -1
#     PrimalIntegral  : 52.755405096657285
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/mc7_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 108.84130442556582
#     ExecTime        : 11.5
#     Calls           : 26.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 108.64909254968916
#     ExecTime        : 9.5
#     Calls           : 25.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 97.01277877388145
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/mc8_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 52.45904065957548
#     ExecTime        : 17.0
#     Calls           : 61.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 49.96075963709512
#     ExecTime        : 11.0
#     Calls           : 39.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 56.77999176898021
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/mcsched_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 15.993861441810317
#     ExecTime        : 4.5
#     Calls           : 22.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 16.366507403703025
#     ExecTime        : 3.0
#     Calls           : 43.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 17.022195532962897
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/mik-250-20-75-4_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 2.5668081857065053
#     ExecTime        : 4.5
#     Calls           : 329.0
#     Found           : 163.0
#   freq: 10
#     PrimalIntegral  : 2.6207081839765936
#     ExecTime        : 1.5
#     Calls           : 336.5
#     Found           : 101.0
#   freq: -1
#     PrimalIntegral  : 2.1296715159617885
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/milo-v12-6-r2-40-1_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 299.999999999999
#     ExecTime        : 11.0
#     Calls           : 18.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 299.999999999999
#     ExecTime        : 10.5
#     Calls           : 20.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 299.999999999999
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/mine-166-5_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 22.26879259405797
#     ExecTime        : 2.0
#     Calls           : 66.0
#     Found           : 7.0
#   freq: 10
#     PrimalIntegral  : 30.614158027101794
#     ExecTime        : 2.5
#     Calls           : 95.0
#     Found           : 3.5
#   freq: -1
#     PrimalIntegral  : 31.375894815501063
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/mine-90-10_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 35.32816560630121
#     ExecTime        : 6.5
#     Calls           : 302.5
#     Found           : 5.5
#   freq: 10
#     PrimalIntegral  : 48.82670325725277
#     ExecTime        : 4.0
#     Calls           : 162.5
#     Found           : 5.5
#   freq: -1
#     PrimalIntegral  : 68.3466716504347
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/mkc1_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 12.155616841260898
#     ExecTime        : 12.0
#     Calls           : 147.0
#     Found           : 3.0
#   freq: 10
#     PrimalIntegral  : 11.026255740155118
#     ExecTime        : 14.0
#     Calls           : 213.5
#     Found           : 9.0
#   freq: -1
#     PrimalIntegral  : 45.47240996205205
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/momentum1_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 299.99999999999966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/mushroom-best_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 1.5
#     Calls           : 1.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 289.708234887902
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-1171692_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 200.98954760072576
#     ExecTime        : 19.0
#     Calls           : 19.5
#     Found           : 2.0
#   freq: 10
#     PrimalIntegral  : 249.94379124784243
#     ExecTime        : 19.0
#     Calls           : 19.0
#     Found           : 0.5
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-1224597_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 55.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 45.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 56.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-1225589_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 14.723854279177058
#     ExecTime        : 4.5
#     Calls           : 771.5
#     Found           : 155.0
#   freq: 10
#     PrimalIntegral  : 7.865215969522205
#     ExecTime        : 4.5
#     Calls           : 598.0
#     Found           : 57.0
#   freq: -1
#     PrimalIntegral  : 3.7210256520863028
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-1426635_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 2.0625
#     ExecTime        : 20.0
#     Calls           : 5704.5
#     Found           : 1.5
#   freq: 10
#     PrimalIntegral  : 2.0142045454545454
#     ExecTime        : 16.0
#     Calls           : 5232.0
#     Found           : 0.5
#   freq: -1
#     PrimalIntegral  : 2.53125
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-1426662_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 14.386363636363637
#     ExecTime        : 23.0
#     Calls           : 336.0
#     Found           : 4.0
#   freq: 10
#     PrimalIntegral  : 16.125000000000007
#     ExecTime        : 15.5
#     Calls           : 351.0
#     Found           : 3.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-1436709_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 4.8031472978329806
#     ExecTime        : 21.0
#     Calls           : 1116.0
#     Found           : 2.5
#   freq: 10
#     PrimalIntegral  : 5.407552083333333
#     ExecTime        : 21.0
#     Calls           : 919.0
#     Found           : 2.5
#   freq: -1
#     PrimalIntegral  : 9.1884765625
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-1440225_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 285.0
#     ExecTime        : 0.5
#     Calls           : 2.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 279.0
#     ExecTime        : 1.0
#     Calls           : 3.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 195.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-1440460_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 4.078800557880056
#     ExecTime        : 20.0
#     Calls           : 1602.5
#     Found           : 1.0
#   freq: 10
#     PrimalIntegral  : 4.135285913528591
#     ExecTime        : 21.0
#     Calls           : 1331.5
#     Found           : 1.0
#   freq: -1
#     PrimalIntegral  : 5.774855548914127
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-1442657_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 7.636461704422868
#     ExecTime        : 17.0
#     Calls           : 849.5
#     Found           : 0.5
#   freq: 10
#     PrimalIntegral  : 5.176144244105405
#     ExecTime        : 17.5
#     Calls           : 811.5
#     Found           : 2.5
#   freq: -1
#     PrimalIntegral  : 5.6029126213592235
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-1605075_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-1616732_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 6.413320988747927
#     ExecTime        : 2.5
#     Calls           : 282.5
#     Found           : 0.5
#   freq: 10
#     PrimalIntegral  : 7.2479239910809365
#     ExecTime        : 5.0
#     Calls           : 472.0
#     Found           : 1.0
#   freq: -1
#     PrimalIntegral  : 6.299694748658299
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-1620770_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 17.55681818181818
#     ExecTime        : 14.5
#     Calls           : 1305.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 16.0
#     ExecTime        : 4.5
#     Calls           : 677.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 18.006087333718913
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-2978193-inde_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 26.33497346586552
#     ExecTime        : 14.5
#     Calls           : 53.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 18.137697391728583
#     ExecTime        : 8.0
#     Calls           : 52.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 20.333960839596216
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-2987310-joes_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 8.500000004362619
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 10.50000000433269
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 12.500000004302759
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3004026-krka_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 171.0
#     ExecTime        : 4.0
#     Calls           : 9.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 262.5
#     ExecTime        : 3.5
#     Calls           : 10.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 192.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3024952-loue_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 299.99999999999994
#     ExecTime        : 11.0
#     Calls           : 12.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 299.99999999999994
#     ExecTime        : 7.5
#     Calls           : 10.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 299.99999999999994
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3046601-motu_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 25.513460318832145
#     ExecTime        : 14.5
#     Calls           : 2218.5
#     Found           : 13.0
#   freq: 10
#     PrimalIntegral  : 27.952912841312248
#     ExecTime        : 9.5
#     Calls           : 1724.5
#     Found           : 9.0
#   freq: -1
#     PrimalIntegral  : 87.63485006613801
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3046615-murg_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 20.724973172146804
#     ExecTime        : 20.0
#     Calls           : 1271.5
#     Found           : 12.0
#   freq: 10
#     PrimalIntegral  : 19.649150884475922
#     ExecTime        : 14.5
#     Calls           : 1352.5
#     Found           : 13.0
#   freq: -1
#     PrimalIntegral  : 70.35207481254393
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3072252-nete_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 8.884710869408577
#     ExecTime        : 160.5
#     Calls           : 270.5
#     Found           : 23.5
#   freq: 10
#     PrimalIntegral  : 10.200289670847452
#     ExecTime        : 141.0
#     Calls           : 189.0
#     Found           : 14.5
#   freq: -1
#     PrimalIntegral  : 243.06032054394024
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3083819-nubu_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 37.03659086202113
#     ExecTime        : 1.0
#     Calls           : 22.0
#     Found           : 1.5
#   freq: 10
#     PrimalIntegral  : 26.045579183256862
#     ExecTime        : 1.0
#     Calls           : 27.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 26.591791869981854
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3118745-obra_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 17.715707773158158
#     ExecTime        : 11.5
#     Calls           : 429.0
#     Found           : 94.5
#   freq: 10
#     PrimalIntegral  : 19.092616654345356
#     ExecTime        : 8.5
#     Calls           : 427.0
#     Found           : 72.0
#   freq: -1
#     PrimalIntegral  : 23.29136479345567
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3209519-ruhr_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 43.23024700886519
#     ExecTime        : 5.5
#     Calls           : 27.5
#     Found           : 0.5
#   freq: 10
#     PrimalIntegral  : 48.94621721632179
#     ExecTime        : 5.0
#     Calls           : 28.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 31.923577400829554
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3216931-puriri_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 299.9999999999998
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 299.9999999999998
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 299.9999999999998
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3226448-wkra_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3381206-awhea_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 239.18498942917546
#     ExecTime        : 24.0
#     Calls           : 31.5
#     Found           : 1.0
#   freq: 10
#     PrimalIntegral  : 183.7744915142752
#     ExecTime        : 26.5
#     Calls           : 54.5
#     Found           : 2.5
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3530903-gauja_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 125.388717055382
#     ExecTime        : 16.5
#     Calls           : 86.0
#     Found           : 2.5
#   freq: 10
#     PrimalIntegral  : 186.77710656825
#     ExecTime        : 17.5
#     Calls           : 68.5
#     Found           : 2.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3581454-haast_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 262.86407766990294
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 132.71138413015936
#     ExecTime        : 4.0
#     Calls           : 16.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3627168-kasai_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 18.39385227568423
#     ExecTime        : 16.0
#     Calls           : 716.5
#     Found           : 79.0
#   freq: 10
#     PrimalIntegral  : 17.613909620843735
#     ExecTime        : 26.5
#     Calls           : 811.5
#     Found           : 136.5
#   freq: -1
#     PrimalIntegral  : 258.38890523833317
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3660371-kurow_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 38.011997718314284
#     ExecTime        : 6.0
#     Calls           : 560.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 51.565243515936864
#     ExecTime        : 4.5
#     Calls           : 607.0
#     Found           : 2.0
#   freq: -1
#     PrimalIntegral  : 45.9727548824834
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3665875-lesum_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 162.88471307884924
#     ExecTime        : 11.0
#     Calls           : 168.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 193.5527391807447
#     ExecTime        : 6.5
#     Calls           : 107.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 179.7661867735947
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-3759587-noosa_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 27.500000003382695
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 24.000000003426145
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 30.50000000334545
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-4333464-siret_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 86.77188057058127
#     ExecTime        : 21.5
#     Calls           : 58.0
#     Found           : 1.0
#   freq: 10
#     PrimalIntegral  : 66.07291526829894
#     ExecTime        : 29.5
#     Calls           : 53.0
#     Found           : 2.5
#   freq: -1
#     PrimalIntegral  : 213.78426106064586
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-4333596-skien_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 18.005040666339664
#     ExecTime        : 13.5
#     Calls           : 1245.5
#     Found           : 2.0
#   freq: 10
#     PrimalIntegral  : 17.00590929228256
#     ExecTime        : 10.5
#     Calls           : 1066.0
#     Found           : 2.5
#   freq: -1
#     PrimalIntegral  : 6.014111079716604
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-4359986-taipa_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-4393408-tinui_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 18.87013145937983
#     ExecTime        : 11.5
#     Calls           : 375.0
#     Found           : 4.0
#   freq: 10
#     PrimalIntegral  : 12.509944268875795
#     ExecTime        : 18.5
#     Calls           : 542.5
#     Found           : 6.0
#   freq: -1
#     PrimalIntegral  : 38.029173119382854
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-4408804-prosna_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-476283_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-506422_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 75.5
#     ExecTime        : 6.0
#     Calls           : 45.0
#     Found           : 2.5
#   freq: 10
#     PrimalIntegral  : 129.5
#     ExecTime        : 5.0
#     Calls           : 88.5
#     Found           : 2.5
#   freq: -1
#     PrimalIntegral  : 270.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/neos-520729_freq_seedx_veclendiving_1.txt
#   freq: 1
# ...
#   freq: 1
#     PrimalIntegral  : 4.663102597031788
#     ExecTime        : 22.5
#     Calls           : 774.0
#     Found           : 123.5
#   freq: 10
#     PrimalIntegral  : 6.834608094766841
#     ExecTime        : 15.0
#     Calls           : 488.5
#     Found           : 114.0
#   freq: -1
#     PrimalIntegral  : 4.45507702647239
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/peg-solitaire-a3_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/pg5_34_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 35.877511870501536
#     ExecTime        : 33.5
#     Calls           : 45.5
#     Found           : 3.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 15.0
#     Calls           : 15.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/pg_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 109.4194411659293
#     ExecTime        : 35.0
#     Calls           : 35.5
#     Found           : 1.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 13.5
#     Calls           : 13.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/physiciansched5-3_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 299.99999999999994
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 299.99999999999994
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 299.99999999999994
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/pigeon-08_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 2.0
#     ExecTime        : 2.5
#     Calls           : 628.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 2.0
#     ExecTime        : 0.5
#     Calls           : 608.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 2.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/pigeon-10_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 2.5
#     ExecTime        : 3.5
#     Calls           : 822.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 2.5
#     ExecTime        : 4.5
#     Calls           : 880.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 2.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/pigeon-13_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 4.5
#     ExecTime        : 10.0
#     Calls           : 1255.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 12.5
#     ExecTime        : 13.0
#     Calls           : 1071.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 5.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/pigeon-16_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 17.0
#     ExecTime        : 14.5
#     Calls           : 748.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 7.5
#     ExecTime        : 9.0
#     Calls           : 326.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 6.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/pigeon-20_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 16.0
#     ExecTime        : 8.5
#     Calls           : 267.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 56.0
#     ExecTime        : 15.0
#     Calls           : 596.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 19.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/piperout-03_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 74.09589104886221
#     ExecTime        : 0.5
#     Calls           : 0.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 75.79233618951275
#     ExecTime        : 0.0
#     Calls           : 0.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 141.79793318022743
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/piperout-08_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 163.78453291049956
#     ExecTime        : 1.0
#     Calls           : 4.0
#     Found           : 1.5
#   freq: 10
#     PrimalIntegral  : 126.49843045890981
#     ExecTime        : 1.0
#     Calls           : 2.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 140.86821858190183
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/piperout-27_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 71.64837306398371
#     ExecTime        : 0.5
#     Calls           : 1.5
#     Found           : 0.5
#   freq: 10
#     PrimalIntegral  : 77.78692339255184
#     ExecTime        : 0.0
#     Calls           : 4.0
#     Found           : 2.5
#   freq: -1
#     PrimalIntegral  : 98.41427747407735
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/piperout-d20_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 275.30348093015465
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 280.5349814752859
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 288.12787338005467
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/piperout-d27_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 279.2712160216156
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 279.77138424323107
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 294.0866130493707
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/pk1_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 100.33323692131073
#     ExecTime        : 0.5
#     Calls           : 1391.5
#     Found           : 10.5
#   freq: 10
#     PrimalIntegral  : 17.798273236789466
#     ExecTime        : 10.0
#     Calls           : 3833.0
#     Found           : 13.5
#   freq: -1
#     PrimalIntegral  : 45.44108047897524
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/prod1_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 3.1785714285714284
#     ExecTime        : 2.5
#     Calls           : 423.5
#     Found           : 2.0
#   freq: 10
#     PrimalIntegral  : 3.4375
#     ExecTime        : 2.5
#     Calls           : 396.0
#     Found           : 2.0
#   freq: -1
#     PrimalIntegral  : 3.9107142857142856
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/prod2_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 17.814516129032256
#     ExecTime        : 24.0
#     Calls           : 2732.5
#     Found           : 7.5
#   freq: 10
#     PrimalIntegral  : 21.749999999999996
#     ExecTime        : 17.5
#     Calls           : 2033.5
#     Found           : 8.5
#   freq: -1
#     PrimalIntegral  : 31.24193548387096
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/pw-myciel4_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 65.42992424242425
#     ExecTime        : 3.5
#     Calls           : 104.5
#     Found           : 3.5
#   freq: 10
#     PrimalIntegral  : 38.319347319347315
#     ExecTime        : 4.5
#     Calls           : 114.5
#     Found           : 0.5
#   freq: -1
#     PrimalIntegral  : 15.146853146853147
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/qap10_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 57.000000000000206
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 56.50000000000021
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 64.50000000000038
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/square31_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/square37_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/square41_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/square47_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/supportcase17_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 36.504126928479806
#     ExecTime        : 2.5
#     Calls           : 96.0
#     Found           : 3.0
#   freq: 10
#     PrimalIntegral  : 34.4110479664532
#     ExecTime        : 4.0
#     Calls           : 87.5
#     Found           : 3.5
#   freq: -1
#     PrimalIntegral  : 30.9616310679053
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/supportcase18_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 170.65869059488202
#     ExecTime        : 1.5
#     Calls           : 5.5
#     Found           : 1.5
#   freq: 10
#     PrimalIntegral  : 113.9958156886469
#     ExecTime        : 3.0
#     Calls           : 6.5
#     Found           : 2.5
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/supportcase20_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 142.8930263917764
#     ExecTime        : 1.5
#     Calls           : 6.0
#     Found           : 9.0
#   freq: 10
#     PrimalIntegral  : 151.4741879443136
#     ExecTime        : 0.5
#     Calls           : 2.5
#     Found           : 6.5
#   freq: -1
#     PrimalIntegral  : 149.8913479274652
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/supportcase26_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 25.190040286602542
#     ExecTime        : 22.5
#     Calls           : 1307.0
#     Found           : 6.5
#   freq: 10
#     PrimalIntegral  : 21.474088460073688
#     ExecTime        : 20.0
#     Calls           : 1319.5
#     Found           : 6.0
#   freq: -1
#     PrimalIntegral  : 122.79768436065966
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/supportcase33_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 103.07246376811594
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 131.76086956521738
#     ExecTime        : 0.5
#     Calls           : 1.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 154.02898550724638
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/supportcase34_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/supportcase37_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 57.90007721934106
#     ExecTime        : 0.5
#     Calls           : 0.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 58.551412827943835
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 63.302084922208586
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/supportcase40_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 22.659116133441902
#     ExecTime        : 1.0
#     Calls           : 2.0
#     Found           : 0.5
#   freq: 10
#     PrimalIntegral  : 29.622332126860016
#     ExecTime        : 0.0
#     Calls           : 1.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 41.03834872508731
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/supportcase42_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/supportcase4_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 300.0
#     ExecTime        : 0.0
#     Calls           : 12.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 287.5
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/swath1_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 5.056328662447301
#     ExecTime        : 0.0
#     Calls           : 8.0
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 5.699549811216303
#     ExecTime        : 0.0
#     Calls           : 0.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 4.591806442968938
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/swath2_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 5.003902580189043
#     ExecTime        : 1.0
#     Calls           : 10.5
#     Found           : 0.0
#   freq: 10
#     PrimalIntegral  : 5.190087788058232
#     ExecTime        : 1.5
#     Calls           : 11.5
#     Found           : 0.0
#   freq: -1
#     PrimalIntegral  : 5.251535345316462
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0
# Instance:  results/swath3_freq_seedx_veclendiving_1.txt
#   freq: 1
#     PrimalIntegral  : 8.224349139350494
#     ExecTime        : 1.5
#     Calls           : 16.5
#     Found           : 0.5
#   freq: 10
#     PrimalIntegral  : 8.167107378931668
#     ExecTime        : 4.0
#     Calls           : 34.0
#     Found           : 0.5
#   freq: -1
#     PrimalIntegral  : 7.577672191751844
#     ExecTime        : 0.0
#     Calls           : 0.0
#     Found           : 0.0

# %%
for val in [1, 10, -1]:
    
    avg = stats[np.abs(stats['veclendiving_freq'] - val) <= 1e-2].mean()
    
    print('freq:', val)
    print('  PrimalIntegral  :', avg['PrimalIntegral'])
    print('  ExecTime        :', avg['ExecTime'])
    print('  Calls           :', avg['Calls'])
    print('  Found           :', avg['Found'])
# Out:
# freq: 1
#   PrimalIntegral  : 108.74032764711185
#   ExecTime        : 47.6
#   Calls           : 158.8
#   Found           : 13.8
# freq: 10
#   PrimalIntegral  : 79.00524371602965
#   ExecTime        : 24.0
#   Calls           : 303.4
#   Found           : 13.6
# freq: -1
#   PrimalIntegral  : 262.58682222399943
#   ExecTime        : 0.0
#   Calls           : 0.0
#   Found           : 0.0

# %%
data/miplib_2017/collection/sp98ar.mps
data/miplib_2017/collection/square23.mps
